# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
train = pd.read_csv("park_data/train.csv")
test = pd.read_csv("park_data/test.csv")
age_gender = pd.read_csv("park_data/age_gender_info.csv")
sub = pd.read_csv("park_data/sample_submission.csv")

# %% [markdown]
# ### train 데이터의 오류코드 제거

# %%
train = train.loc[~((train['단지코드']=='C1095')|(train['단지코드']=='C2051')|
          (train['단지코드']=='C1218')|(train['단지코드']=='C1894')|
          (train['단지코드']=='C2483')|(train['단지코드']=='C1502')|
          (train['단지코드']=='C1988')|(train['단지코드']=='C2085')|
          (train['단지코드']=='C1397')|(train['단지코드']=='C2431')|
          (train['단지코드']=='C1649')|(train['단지코드']=='C1036')),:]

# %%
train.reset_index(inplace=True)
train
# Out:
#       index   단지코드  총세대수 임대건물구분    지역  공급유형   전용면적  전용면적별세대수   공가수 자격유형  \
# 0         8  C2515   545    아파트  경상남도  국민임대  33.48       276  17.0    A
# 1         9  C2515   545    아파트  경상남도  국민임대  39.60        60  17.0    A
# 2        10  C2515   545    아파트  경상남도  국민임대  39.60        20  17.0    A
# 3        11  C2515   545    아파트  경상남도  국민임대  46.90        38  17.0    A
# 4        12  C2515   545    아파트  경상남도  국민임대  46.90        19  17.0    A
# ...     ...    ...   ...    ...   ...   ...    ...       ...   ...  ...
# 2864   2947  C2532   239    아파트   강원도  국민임대  49.20        19   7.0    A
# 2865   2948  C2532   239    아파트   강원도  국민임대  51.08        34   7.0    A
# 2866   2949  C2532   239    아파트   강원도  국민임대  51.73        34   7.0    A
# 2867   2950  C2532   239    아파트   강원도  국민임대  51.96       114   7.0    A
# 2868   2951  C2532   239    아파트   강원도  국민임대  54.95        19   7.0    A
#
#          임대보증금     임대료  도보 10분거리 내 지하철역 수(환승노선 수 반영)  도보 10분거리 내 버스정류장 수  \
# ...

# %%
del train['index']

# %%
train
# Out:
#        단지코드  총세대수 임대건물구분    지역  공급유형   전용면적  전용면적별세대수   공가수 자격유형     임대보증금  \
# 0     C2515   545    아파트  경상남도  국민임대  33.48       276  17.0    A   9216000
# 1     C2515   545    아파트  경상남도  국민임대  39.60        60  17.0    A  12672000
# 2     C2515   545    아파트  경상남도  국민임대  39.60        20  17.0    A  12672000
# 3     C2515   545    아파트  경상남도  국민임대  46.90        38  17.0    A  18433000
# 4     C2515   545    아파트  경상남도  국민임대  46.90        19  17.0    A  18433000
# ...     ...   ...    ...   ...   ...    ...       ...   ...  ...       ...
# 2864  C2532   239    아파트   강원도  국민임대  49.20        19   7.0    A  11346000
# 2865  C2532   239    아파트   강원도  국민임대  51.08        34   7.0    A  14005000
# 2866  C2532   239    아파트   강원도  국민임대  51.73        34   7.0    A  14005000
# 2867  C2532   239    아파트   강원도  국민임대  51.96       114   7.0    A  14005000
# 2868  C2532   239    아파트   강원도  국민임대  54.95        19   7.0    A  14830000
#
# ...

# %%
test
# Out:
#        단지코드  총세대수 임대건물구분    지역  공급유형   전용면적  전용면적별세대수   공가수 자격유형     임대보증금  \
# 0     C1072   754    아파트   경기도  국민임대  39.79       116  14.0    H  22830000
# 1     C1072   754    아파트   경기도  국민임대  46.81        30  14.0    A  36048000
# 2     C1072   754    아파트   경기도  국민임대  46.90       112  14.0    H  36048000
# 3     C1072   754    아파트   경기도  국민임대  46.90       120  14.0    H  36048000
# 4     C1072   754    아파트   경기도  국민임대  51.46        60  14.0    H  43497000
# ...     ...   ...    ...   ...   ...    ...       ...   ...  ...       ...
# 1017  C1267   675    아파트  경상남도  행복주택  36.77       126  38.0    L         -
# 1018  C2189   382    아파트  전라북도  국민임대  29.19        96  45.0    H   6872000
# 1019  C2189   382    아파트  전라북도  국민임대  29.19        20  45.0    H   6872000
# 1020  C2189   382    아파트  전라북도  국민임대  39.45       202  45.0    H  13410000
# 1021  C2189   382    아파트  전라북도  국민임대  46.23        60  45.0    H  18689000
#
# ...

# %% [markdown]
# ### test 데이터 오류코드 제거

# %%
test.loc[ ((test['단지코드']=='C2675') | 
           (test['단지코드']=='C2335') |
           (test['단지코드']=='C1327') ) , :]
# Out:
#       단지코드  총세대수 임대건물구분     지역  공급유형   전용면적  전용면적별세대수   공가수 자격유형     임대보증금  \
# 579  C2675   512    아파트    경기도  국민임대  36.65       130   9.0    A  18476000
# 580  C2675   512    아파트    경기도  국민임대  46.90        44   9.0    A  34082000
# 581  C2675   512    아파트    경기도  국민임대  46.90        80   9.0    A  34082000
# 582  C2675   512    아파트    경기도  국민임대  46.90        50   9.0    A  34082000
# 583  C2675   512    아파트    경기도  국민임대  46.90        88   9.0    A  34082000
# 584  C2675   512    아파트    경기도  국민임대  47.40        30   9.0    A  34082000
# 585  C2675   512    아파트    경기도  국민임대  51.93        75   9.0    A  43819000
# 586  C2675   512    아파트    경기도  국민임대  51.93        15   9.0    A  43819000
# 891  C1327    98    아파트  대전광역시  행복주택  16.83        30  13.0    J  18800000
# 892  C1327    98    아파트  대전광역시  행복주택  26.51        10  13.0    J  28400000
# 893  C1327    98    아파트  대전광역시  행복주택  26.51        10  13.0    J  28400000
# ...

# %%
test = test.loc[ ~((test['단지코드']=='C2675') | 
           (test['단지코드']=='C2335') |
           (test['단지코드']=='C1327') ) , :]

# %%
test.iloc[938:,:]
# Out:
#        단지코드  총세대수 임대건물구분     지역  공급유형   전용면적  전용면적별세대수   공가수 자격유형     임대보증금  \
# 950   C2091   150    아파트   충청북도  국민임대  43.33        40   4.0    A  14920000
# 951   C2091   150    아파트   충청북도  영구임대  24.54        18   4.0    C   9150000
# 952   C2091   150    아파트   충청북도  행복주택  26.11        18   4.0    L  14145000
# 955   C1841   100    아파트  광주광역시  행복주택  16.80        40  14.0    J  16768000
# 956   C1841   100    아파트  광주광역시  행복주택  26.97         6  14.0    J  25504000
# ...     ...   ...    ...    ...   ...    ...       ...   ...  ...       ...
# 1017  C1267   675    아파트   경상남도  행복주택  36.77       126  38.0    L         -
# 1018  C2189   382    아파트   전라북도  국민임대  29.19        96  45.0    H   6872000
# 1019  C2189   382    아파트   전라북도  국민임대  29.19        20  45.0    H   6872000
# 1020  C2189   382    아파트   전라북도  국민임대  39.45       202  45.0    H  13410000
# 1021  C2189   382    아파트   전라북도  국민임대  46.23        60  45.0    H  18689000
#
# ...

# %%
test.reset_index(inplace=True)
test
# Out:
#       index   단지코드  총세대수 임대건물구분    지역  공급유형   전용면적  전용면적별세대수   공가수 자격유형  \
# 0         0  C1072   754    아파트   경기도  국민임대  39.79       116  14.0    H
# 1         1  C1072   754    아파트   경기도  국민임대  46.81        30  14.0    A
# 2         2  C1072   754    아파트   경기도  국민임대  46.90       112  14.0    H
# 3         3  C1072   754    아파트   경기도  국민임대  46.90       120  14.0    H
# 4         4  C1072   754    아파트   경기도  국민임대  51.46        60  14.0    H
# ...     ...    ...   ...    ...   ...   ...    ...       ...   ...  ...
# 1003   1017  C1267   675    아파트  경상남도  행복주택  36.77       126  38.0    L
# 1004   1018  C2189   382    아파트  전라북도  국민임대  29.19        96  45.0    H
# 1005   1019  C2189   382    아파트  전라북도  국민임대  29.19        20  45.0    H
# 1006   1020  C2189   382    아파트  전라북도  국민임대  39.45       202  45.0    H
# 1007   1021  C2189   382    아파트  전라북도  국민임대  46.23        60  45.0    H
#
#          임대보증금     임대료  도보 10분거리 내 지하철역 수(환승노선 수 반영)  도보 10분거리 내 버스정류장 수  \
# ...

# %%
del test['index']

# %%
test
# Out:
#        단지코드  총세대수 임대건물구분    지역  공급유형   전용면적  전용면적별세대수   공가수 자격유형     임대보증금  \
# 0     C1072   754    아파트   경기도  국민임대  39.79       116  14.0    H  22830000
# 1     C1072   754    아파트   경기도  국민임대  46.81        30  14.0    A  36048000
# 2     C1072   754    아파트   경기도  국민임대  46.90       112  14.0    H  36048000
# 3     C1072   754    아파트   경기도  국민임대  46.90       120  14.0    H  36048000
# 4     C1072   754    아파트   경기도  국민임대  51.46        60  14.0    H  43497000
# ...     ...   ...    ...   ...   ...    ...       ...   ...  ...       ...
# 1003  C1267   675    아파트  경상남도  행복주택  36.77       126  38.0    L         -
# 1004  C2189   382    아파트  전라북도  국민임대  29.19        96  45.0    H   6872000
# 1005  C2189   382    아파트  전라북도  국민임대  29.19        20  45.0    H   6872000
# 1006  C2189   382    아파트  전라북도  국민임대  39.45       202  45.0    H  13410000
# 1007  C2189   382    아파트  전라북도  국민임대  46.23        60  45.0    H  18689000
#
# ...

# %%
train.loc[(train['단지코드']=='C2085')|(train['단지코드']=='C1397')
          |(train['단지코드']=='C2431')|(train['단지코드']=='C1649')
          |(train['단지코드']=='C1036'),:]
# Out:
# Empty DataFrame
# Columns: [단지코드, 총세대수, 임대건물구분, 지역, 공급유형, 전용면적, 전용면적별세대수, 공가수, 자격유형, 임대보증금, 임대료, 도보 10분거리 내 지하철역 수(환승노선 수 반영), 도보 10분거리 내 버스정류장 수, 단지내주차면수, 등록차량수]
# Index: []

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2869 entries, 0 to 2868
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   단지코드                          2869 non-null   object
#  1   총세대수                          2869 non-null   int64
#  2   임대건물구분                        2869 non-null   object
#  3   지역                            2869 non-null   object
#  4   공급유형                          2869 non-null   object
#  5   전용면적                          2869 non-null   float64
#  6   전용면적별세대수                      2869 non-null   int64
#  7   공가수                           2869 non-null   float64
#  8   자격유형                          2869 non-null   object
#  9   임대보증금                         2300 non-null   object
#  10  임대료                           2300 non-null   object
#  11  도보 10분거리 내 지하철역 수(환승노선 수 반영)  2662 non-null   float64
# ...

# %% [markdown]
# ### csv파일로 다시저장

# %%
train_df = train.copy()
test_df = test.copy()

# %%
train_df.to_csv('train_df.csv', index=False)
test_df.to_csv('test_df.csv', index=False)
